# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing

plt.rc('font', size=8)          # controls default text sizes
plt.rc('axes', titlesize=8)     # fontsize of the axes title
plt.rc('axes', labelsize=15)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=8)    # fontsize of the tick labels
plt.rc('ytick', labelsize=8)    # fontsize of the tick labels
plt.rc('legend', fontsize=10)    # legend fontsize
plt.rc('figure', titlesize=20)  # fontsize of the figure title

# %%
incomedf = pd.read_csv('data/london_taxpayer_income.csv')
jobsdf = pd.read_csv('data/Jobs_and_Job_Density.csv')

# %%
plt.figure(figsize=(20,20))
plt.plot(incomedf[incomedf['area']=='Newham']['year'],incomedf[incomedf['area']=='Newham']['median_income'].pct_change(),label='Newham')
plt.plot(incomedf[incomedf['area']=='Hackney']['year'],incomedf[incomedf['area']=='Hackney']['median_income'].pct_change(),label='Hackney')
plt.plot(incomedf[incomedf['area']=='Hillingdon']['year'],incomedf[incomedf['area']=='Hillingdon']['median_income'].pct_change(),label='Hillingdon')
plt.plot(incomedf[incomedf['area']=='Sutton']['year'],incomedf[incomedf['area']=='Sutton']['median_income'].pct_change(),label='Sutton')
plt.plot(incomedf[incomedf['area']=='Croydon']['year'],incomedf[incomedf['area']=='Croydon']['median_income'].pct_change(),label='Croydon')
plt.plot(incomedf[incomedf['area']=='City of London']['year'],incomedf[incomedf['area']=='City of London']['median_income'].pct_change(),label='City of London')
plt.plot(incomedf[incomedf['area']=='Westminster']['year'],incomedf[incomedf['area']=='Westminster']['median_income'].pct_change(),label='Westminster')
plt.xlabel('Year')
plt.ylabel('Percentage change in Median Income')
plt.legend()
# plt.savefig('pctchngmdincome.png')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.plot(incomedf[incomedf['area']=='Newham']['year'].iloc[10:],incomedf[incomedf['area']=='Newham']['median_income'].iloc[10:]/incomedf[incomedf['area']=='Newham']['median_income'].iloc[10],label='Newham')
plt.plot(incomedf[incomedf['area']=='Hackney']['year'].iloc[10:],incomedf[incomedf['area']=='Hackney']['median_income'].iloc[10:]/incomedf[incomedf['area']=='Hackney']['median_income'].iloc[10],label='Hackney')
plt.plot(incomedf[incomedf['area']=='Hillingdon']['year'].iloc[10:],incomedf[incomedf['area']=='Hillingdon']['median_income'].iloc[10:]/incomedf[incomedf['area']=='Hillingdon']['median_income'].iloc[10],label='Hillingdon')
plt.plot(incomedf[incomedf['area']=='Sutton']['year'].iloc[10:],incomedf[incomedf['area']=='Sutton']['median_income'].iloc[10:]/incomedf[incomedf['area']=='Sutton']['median_income'].iloc[10],label='Sutton')
plt.plot(incomedf[incomedf['area']=='Croydon']['year'].iloc[10:],incomedf[incomedf['area']=='Croydon']['median_income'].iloc[10:]/incomedf[incomedf['area']=='Croydon']['median_income'].iloc[10],label='Croydon')
plt.plot(incomedf[incomedf['area']=='City of London']['year'].iloc[10:],incomedf[incomedf['area']=='City of London']['median_income'].iloc[10:]/incomedf[incomedf['area']=='City of London']['median_income'].iloc[10],label='City of London')
plt.plot(incomedf[incomedf['area']=='Westminster']['year'].iloc[10:],incomedf[incomedf['area']=='Westminster']['median_income'].iloc[10:]/incomedf[incomedf['area']=='Westminster']['median_income'].iloc[10],label='Westminster')
plt.plot(incomedf[incomedf['area']=='London']['year'].iloc[10:],incomedf[incomedf['area']=='London']['median_income'].iloc[10:]/incomedf[incomedf['area']=='London']['median_income'].iloc[10],label='London')
plt.xlabel('Year')
plt.ylabel('Median Income (Normalized)')
plt.legend()
# plt.savefig('mdincomen.png')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.plot(incomedf[incomedf['area']=='Newham']['year'],incomedf[incomedf['area']=='Newham']['mean_income'].pct_change(),label='Newham')
plt.plot(incomedf[incomedf['area']=='Hackney']['year'],incomedf[incomedf['area']=='Hackney']['mean_income'].pct_change(),label='Hackney')
plt.plot(incomedf[incomedf['area']=='Hillingdon']['year'],incomedf[incomedf['area']=='Hillingdon']['mean_income'].pct_change(),label='Hillingdon')
plt.plot(incomedf[incomedf['area']=='Sutton']['year'],incomedf[incomedf['area']=='Sutton']['mean_income'].pct_change(),label='Sutton')
plt.plot(incomedf[incomedf['area']=='Croydon']['year'],incomedf[incomedf['area']=='Croydon']['mean_income'].pct_change(),label='Croydon')
plt.plot(incomedf[incomedf['area']=='City of London']['year'],incomedf[incomedf['area']=='City of London']['mean_income'].pct_change(),label='City of London')
plt.plot(incomedf[incomedf['area']=='Westminster']['year'],incomedf[incomedf['area']=='Westminster']['mean_income'].pct_change(),label='Westminster')
plt.xlabel('Year')
plt.ylabel('Percentage change in Mean Income')
plt.legend()
# plt.savefig('pctchngmdincome.png')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.plot(incomedf[incomedf['area']=='Newham']['year'].iloc[10:],incomedf[incomedf['area']=='Newham']['mean_income'].iloc[10:]/incomedf[incomedf['area']=='Newham']['mean_income'].iloc[10],label='Newham')
plt.plot(incomedf[incomedf['area']=='Hackney']['year'].iloc[10:],incomedf[incomedf['area']=='Hackney']['mean_income'].iloc[10:]/incomedf[incomedf['area']=='Hackney']['mean_income'].iloc[10],label='Hackney')
plt.plot(incomedf[incomedf['area']=='Hillingdon']['year'].iloc[10:],incomedf[incomedf['area']=='Hillingdon']['mean_income'].iloc[10:]/incomedf[incomedf['area']=='Hillingdon']['mean_income'].iloc[10],label='Hillingdon')
plt.plot(incomedf[incomedf['area']=='Sutton']['year'].iloc[10:],incomedf[incomedf['area']=='Sutton']['mean_income'].iloc[10:]/incomedf[incomedf['area']=='Sutton']['mean_income'].iloc[10],label='Sutton')
plt.plot(incomedf[incomedf['area']=='Croydon']['year'].iloc[10:],incomedf[incomedf['area']=='Croydon']['mean_income'].iloc[10:]/incomedf[incomedf['area']=='Croydon']['mean_income'].iloc[10],label='Croydon')
plt.plot(incomedf[incomedf['area']=='City of London']['year'].iloc[10:],incomedf[incomedf['area']=='City of London']['mean_income'].iloc[10:]/incomedf[incomedf['area']=='City of London']['mean_income'].iloc[10],label='City of London')
plt.plot(incomedf[incomedf['area']=='Westminster']['year'].iloc[10:],incomedf[incomedf['area']=='Westminster']['mean_income'].iloc[10:]/incomedf[incomedf['area']=='Westminster']['mean_income'].iloc[10],label='Westminster')
plt.plot(incomedf[incomedf['area']=='London']['year'].iloc[10:],incomedf[incomedf['area']=='London']['mean_income'].iloc[10:]/incomedf[incomedf['area']=='London']['mean_income'].iloc[10],label='London')
plt.xlabel('Year')
plt.ylabel('Mean Income (Normalized)')
plt.legend()
# plt.savefig('mnincomen.png')
plt.show()

# %%
plt.figure(figsize=(22,30))
plt.plot(incomedf[incomedf['area']=='Waltham Forest']['year'],incomedf[incomedf['area']=='Waltham Forest']['mean_income'],label='Waltham Forest')
plt.plot(incomedf[incomedf['area']=='Tower Hamlets']['year'],incomedf[incomedf['area']=='Tower Hamlets']['mean_income'],label='Tower Hamlets')
plt.plot(incomedf[incomedf['area']=='Newham']['year'],incomedf[incomedf['area']=='Newham']['mean_income'],label='Newham')
plt.plot(incomedf[incomedf['area']=='Hackney']['year'],incomedf[incomedf['area']=='Hackney']['mean_income'],label='Hackney')
plt.plot(incomedf[incomedf['area']=='Hillingdon']['year'],incomedf[incomedf['area']=='Hillingdon']['mean_income'],label='Hillingdon')
plt.plot(incomedf[incomedf['area']=='Sutton']['year'],incomedf[incomedf['area']=='Sutton']['mean_income'],label='Sutton')
plt.plot(incomedf[incomedf['area']=='Croydon']['year'],incomedf[incomedf['area']=='Croydon']['mean_income'],label='Croydon')
plt.ylabel('Mean Income')
plt.xlabel('Year')
plt.legend()
# plt.savefig('incomevyear.png')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.plot(incomedf[incomedf['area']=='Newham']['year'],incomedf[incomedf['area']=='Newham']['population'].pct_change(),label='Newham')
plt.plot(incomedf[incomedf['area']=='Hackney']['year'],incomedf[incomedf['area']=='Hackney']['population'].pct_change(),label='Hackney')
plt.plot(incomedf[incomedf['area']=='Hillingdon']['year'],incomedf[incomedf['area']=='Hillingdon']['population'].pct_change(),label='Hillingdon')
plt.plot(incomedf[incomedf['area']=='Sutton']['year'],incomedf[incomedf['area']=='Sutton']['population'].pct_change(),label='Sutton')
plt.plot(incomedf[incomedf['area']=='Croydon']['year'],incomedf[incomedf['area']=='Croydon']['population'].pct_change(),label='Croydon')
plt.plot(incomedf[incomedf['area']=='City of London']['year'],incomedf[incomedf['area']=='City of London']['population'].pct_change(),label='City of London')
plt.plot(incomedf[incomedf['area']=='Westminster']['year'],incomedf[incomedf['area']=='Westminster']['population'].pct_change(),label='Westminster')
plt.xlabel('Year')
plt.ylabel('Percentage change in Population')
plt.legend()
# plt.savefig('pctchngpop.png')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.plot(incomedf[incomedf['area']=='Newham']['year'].iloc[10:],incomedf[incomedf['area']=='Newham']['population'].iloc[10:]/incomedf[incomedf['area']=='Newham']['population'].iloc[10],label='Newham')
plt.plot(incomedf[incomedf['area']=='Hackney']['year'].iloc[10:],incomedf[incomedf['area']=='Hackney']['population'].iloc[10:]/incomedf[incomedf['area']=='Hackney']['population'].iloc[10],label='Hackney')
plt.plot(incomedf[incomedf['area']=='Hillingdon']['year'].iloc[10:],incomedf[incomedf['area']=='Hillingdon']['population'].iloc[10:]/incomedf[incomedf['area']=='Hillingdon']['population'].iloc[10],label='Hillingdon')
plt.plot(incomedf[incomedf['area']=='Sutton']['year'].iloc[10:],incomedf[incomedf['area']=='Sutton']['population'].iloc[10:]/incomedf[incomedf['area']=='Sutton']['population'].iloc[10],label='Sutton')
plt.plot(incomedf[incomedf['area']=='Croydon']['year'].iloc[10:],incomedf[incomedf['area']=='Croydon']['population'].iloc[10:]/incomedf[incomedf['area']=='Croydon']['population'].iloc[10],label='Croydon')
plt.plot(incomedf[incomedf['area']=='City of London']['year'].iloc[10:],incomedf[incomedf['area']=='City of London']['population'].iloc[10:]/incomedf[incomedf['area']=='City of London']['population'].iloc[10],label='City of London')
plt.plot(incomedf[incomedf['area']=='Westminster']['year'].iloc[10:],incomedf[incomedf['area']=='Westminster']['population'].iloc[10:]/incomedf[incomedf['area']=='Westminster']['population'].iloc[10],label='Westminster')
plt.plot(incomedf[incomedf['area']=='London']['year'].iloc[10:],incomedf[incomedf['area']=='London']['population'].iloc[10:]/incomedf[incomedf['area']=='London']['population'].iloc[10],label='London')
plt.xlabel('Year')
plt.ylabel('Population (Normalized)')
plt.legend()
# plt.savefig('popn.png')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.plot(jobsdf[jobsdf['area']=='City of London']['year'],jobsdf[jobsdf['area']=='City of London']['number_of_jobs'].pct_change(),label='City of London')
plt.plot(jobsdf[jobsdf['area']=='Westminster']['year'],jobsdf[jobsdf['area']=='Westminster']['number_of_jobs'].pct_change(),label='Westminster')
plt.plot(jobsdf[jobsdf['area']=='Kensington and Chelsea']['year'],jobsdf[jobsdf['area']=='Kensington and Chelsea']['number_of_jobs'].pct_change(),label='Kensington and Chelsea')
plt.plot(jobsdf[jobsdf['area']=='Newham']['year'],jobsdf[jobsdf['area']=='Newham']['number_of_jobs'].pct_change(),label='Newham')
plt.plot(jobsdf[jobsdf['area']=='London']['year'],jobsdf[jobsdf['area']=='London']['number_of_jobs'].pct_change(),label='London')
plt.xticks(np.arange(2000, 2019))
plt.ylabel('Percentage Change in Number of Jobs')
plt.xlabel('Year')
plt.legend()
# plt.savefig('pctchangejobs.png')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.plot(jobsdf[jobsdf['area']=='Newham']['year'].iloc[10:],jobsdf[jobsdf['area']=='Newham']['number_of_jobs'].iloc[10:]/jobsdf[jobsdf['area']=='Newham']['number_of_jobs'].iloc[10],label='Newham')
plt.plot(jobsdf[jobsdf['area']=='Hackney']['year'].iloc[10:],jobsdf[jobsdf['area']=='Hackney']['number_of_jobs'].iloc[10:]/jobsdf[jobsdf['area']=='Hackney']['number_of_jobs'].iloc[10],label='Hackney')
plt.plot(jobsdf[jobsdf['area']=='Hillingdon']['year'].iloc[10:],jobsdf[jobsdf['area']=='Hillingdon']['number_of_jobs'].iloc[10:]/jobsdf[jobsdf['area']=='Hillingdon']['number_of_jobs'].iloc[10],label='Hillingdon')
plt.plot(jobsdf[jobsdf['area']=='Sutton']['year'].iloc[10:],jobsdf[jobsdf['area']=='Sutton']['number_of_jobs'].iloc[10:]/jobsdf[jobsdf['area']=='Sutton']['number_of_jobs'].iloc[10],label='Sutton')
plt.plot(jobsdf[jobsdf['area']=='Croydon']['year'].iloc[10:],jobsdf[jobsdf['area']=='Croydon']['number_of_jobs'].iloc[10:]/jobsdf[jobsdf['area']=='Croydon']['number_of_jobs'].iloc[10],label='Croydon')
plt.plot(jobsdf[jobsdf['area']=='City of London']['year'].iloc[10:],jobsdf[jobsdf['area']=='City of London']['number_of_jobs'].iloc[10:]/jobsdf[jobsdf['area']=='City of London']['number_of_jobs'].iloc[10],label='City of London')
plt.plot(jobsdf[jobsdf['area']=='Westminster']['year'].iloc[10:],jobsdf[jobsdf['area']=='Westminster']['number_of_jobs'].iloc[10:]/jobsdf[jobsdf['area']=='Westminster']['number_of_jobs'].iloc[10],label='Westminster')
plt.plot(jobsdf[jobsdf['area']=='London']['year'].iloc[10:],jobsdf[jobsdf['area']=='London']['number_of_jobs'].iloc[10:]/jobsdf[jobsdf['area']=='London']['number_of_jobs'].iloc[10],label='London')
plt.xlabel('Year')
plt.ylabel('Number of Jobs (Normalized)')
plt.legend()
# plt.savefig('jobsn.png')
plt.show()

# %%
pcdf = pd.DataFrame({'year':incomedf['year'],'area':incomedf['area'],'pc_median_income':incomedf['median_income'].pct_change(),'pc_mean_income':incomedf['mean_income'].pct_change(),'pc_population':incomedf['population'].pct_change()})
print(pcdf[pcdf['year']=='2012-2013'].sort_values(by='pc_mean_income', ascending=False))
# Out:
#           year                      area  pc_median_income  pc_mean_income  \
# 12   2012-2013            City of London          0.129845        0.119658
# 390  2012-2013                   Lambeth          0.056911        0.053221
# 444  2012-2013                    Newham          0.051136        0.050000
# 210  2012-2013                   Hackney          0.042918        0.048077
# 48   2012-2013                    Barnet          0.066116        0.045918
# 588  2012-2013               Westminster          0.086420        0.045351
# 30   2012-2013      Barking and Dagenham          0.025510        0.039474
# 552  2012-2013            Waltham Forest          0.054187        0.035573
# 750  2012-2013                South West          0.035714        0.034483
# 138  2012-2013                   Croydon          0.052863        0.033670
# 84   2012-2013                     Brent          0.019802        0.032847
# ...
